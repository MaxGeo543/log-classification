# %% [markdown]
# First import all neccessary modules

# %%
from datetime import datetime
from preprocessor import Preprocessor
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense, Input
from keras.metrics import Accuracy, Precision, Recall
from keras.callbacks import EarlyStopping, Callback
from keras.utils import Sequence
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from message_encoder import *
from keras.optimizers import Adam, RMSprop, SGD, Nadam
import os
import sys
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
save_artifacts = True

# %% [markdown]
# # Preprocessor
# First we define all hyperparameters used for the preprocessor. If a preprocessor path is defined, the preprocesor will be loaded from that file instead of creating a new preprocessor since that might take a while.

# %%
# hyper parameters
# preprocessing
log_files = [i for i in range(745, 754)]            # list of ints representing the numbers of log files to use
logs_per_class = 100                                # How many datapoints per class should be collected if available
window_size = 20                                    # how many log messages to be considered in a single data point from sliding window
encoding_output_size = 16                           # size to be passed to the message_encoder, note that this is not neccessairily the shape of the output
message_encoder = BERTEncoder(encoding_output_size) # the message_encoder to be used. Can be TextVectorizationEncoder (uses keras.layers.TextVectorizer), BERTEncoder (only uses the BERT tokenizer) or BERTEmbeddingEncoder (also uses the BERT model)
extended_datetime_features = False                  # bool, whether the preprocessing should use a multitude of normalized features extracted from the date 

# preprocessor_file = r"C:\Users\Askion\Documents\agmge\log-classification\data\preprocessors\preprocessor_20_smallest_files_100lpc_20ws_BERTencx16.zip" # if this is a string with content, load the file instead of creating a new preprocessor
preprocessor_file = "../data/preprocessors/preprocessor_20_smallest_files_100lpc_20ws_BERTencx16.zip"

# %% [markdown]
# In the next block data is loaded and preprocessed either using a new preprocessor with the parameters above or using a preprocessor loaded from a file. The former might take a while depending on number and size of the log files.

# %%
# preprocessing
if os.path.isfile(preprocessor_file):
    print("loading preprocessor from file...")
    pp = Preprocessor.load(preprocessor_file)
else:
    pp = Preprocessor(log_files, 
                    message_encoder, 
                    logs_per_class=logs_per_class, 
                    window_size=window_size, 
                    extended_datetime_features=extended_datetime_features, 
                    volatile=True)
    pp.preprocess()

    # save the dataset if it doesn't exist already!
    path = f"./data/preprocessors/preprocessor_{len(pp.loaded_files)}files_"
    m = "BERTenc" if isinstance(pp.message_encoder, BERTEncoder) else "BERTemb" if isinstance(pp.message_encoder, BERTEmbeddingEncoder) else "TextVec" if isinstance(pp.message_encoder, TextVectorizationEncoder) else "enc"
    path += f"_{logs_per_class}lpc_{window_size}ws_{m}x{encoding_output_size}"
    if extended_datetime_features: path += "_extdt"
    path += ".json"
    if not os.path.isfile(path):
        pp.save(path)
# Out:
# loading preprocessor from file...

# %% [markdown]
# # LSTM Architecture
# Next we define the hyperparameters used by the LSTM architecture.

# %%
# lstm architecture
lstm_layers = 1                                     # int, how many lstm layers to use
lstm_units_per_layer = 50                           # int, how many lstm units per layer to use
dropout = 0                                       # float, which dropout value to use, 0.0 is equivalent to not using any dropout
recurrent_dropout = 0                             # float, same as with regular dropout

num_classes = len(set(pp.data.data_array_y))

# %% [markdown]
# Then we can create the model itself using the parameters. The LSTM model is built as a sequential model.

# %%
# lstm architecture
model = Sequential()
input_shape = pp.data.entry_shape

model.add(Input(shape=input_shape))

# First LSTM layer
if lstm_layers > 1:
    model.add(LSTM(lstm_units_per_layer, return_sequences=True, dropout=dropout, recurrent_dropout=recurrent_dropout))
else:
    model.add(LSTM(lstm_units_per_layer, dropout=dropout, recurrent_dropout=recurrent_dropout))  # single layer, no sequences returned
# Intermediate LSTM layers (if any)
for i in range(lstm_layers - 2):
    model.add(LSTM(lstm_units_per_layer, return_sequences=True, dropout=dropout, recurrent_dropout=recurrent_dropout))
# Last LSTM layer (no return_sequences, output fed into Dense)
if lstm_layers > 1:
    model.add(LSTM(lstm_units_per_layer, dropout=dropout, recurrent_dropout=recurrent_dropout))

# Dense Layer
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# # Training
# Next we define the training parameters and split the data into unlabeled, labeled and test data. The unlabeled data currently is just extracted from the dataset while discarding the labels. That is done in order to assure that the class ratios can stay the same.

# %%
class DynamicDataset(Sequence):
    def __init__(self, X, y, batch_size):
        self.X = X
        self.y = y
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.X) / self.batch_size))

    def __getitem__(self, idx):
        batch_x = self.X[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y

    def add_data(self, X_new, y_new):
        self.X = np.concatenate([self.X, X_new])
        self.y = np.concatenate([self.y, y_new])

class PseudoLabelingCallback(Callback):
    def __init__(self, dataset, X_unlabeled, confidence_threshold=0.95, interval=5):
        self.dataset = dataset
        self.X_unlabeled = X_unlabeled
        self.threshold = confidence_threshold
        self.interval = interval

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.interval != 0 or len(self.X_unlabeled) == 0:
            return

        print(f"\n[INFO] Epoch {epoch+1}: Pseudo-labeling unlabeled data...")

        # Predict
        probs = self.model.predict(self.X_unlabeled, verbose=0)
        pseudo_labels = np.argmax(probs, axis=1)
        confidences = np.max(probs, axis=1)
        print("best confidence:", max(confidences))
        # Filter by confidence
        confident_idx = np.where(confidences >= self.threshold)[0]
        if len(confident_idx) == 0:
            print("[INFO] No confident pseudo-labels found.")
            return

        X_confident = self.X_unlabeled[confident_idx]
        y_confident = pseudo_labels[confident_idx]

        print(f"[INFO] Adding {len(confident_idx)} pseudo-labeled samples to training set.")

        # Add to training data
        self.dataset.add_data(X_confident, y_confident)

        # Remove from unlabeled pool
        self.X_unlabeled = np.delete(self.X_unlabeled, confident_idx, axis=0)

# %%
# training parameters
split_ratios = (5, 2, 2, 1)                            # ratio between unlabeled data : labeled data : test data
epochs = 1000                                       # number of iterations to train
batch_size = 32                                     # int, number of samples processed before updating the model weights.
early_stopping_monitor = "val_loss"                 # what value to monitor for early_stopping. can be 'loss', 'val_loss', 'accuracy', 'val_accuracy', 'precision', 'val_precision', 'recall', 'val_recall', 'f1_score', 'val_f1_score'
early_stopping_patience = 200                        # int, number of epochs to wait after no improvement, if this is greater than epochs, EarlyStopping will not apply
early_stopping_restore_best = True                  # bool, if true keeps the best weights, not the final ones.
validation_split = 0.2
learning_rate = 0.001                               # float to specify learning rate of the optimizer
optimizer = Adam(learning_rate=learning_rate)       # optimizer, can be one of Adam, RMSprop, SGD (can have momentum parameter), Nadam

# parameters for semi supervised training
confidence_threshold = 0.95
epochs_total = epochs
epochs_per_cycle = 10

# defining data for training and testing
train_unlabeled, train_labeled, test, validation_data = pp.data.stratified_split(split_ratios)
X_train_labeled, y_train_labeled = (np.copy(t) for t in train_labeled)
X_train_unlabeled, _ = (np.copy(t) for t in train_unlabeled)
X_test, y_test = (np.copy(t) for t in test)
input_shape = pp.data.entry_shape
num_classes = len(set(y_train_labeled))

filename = f"../models/lstm_ss_epc{epochs_per_cycle}_ct{confidence_threshold}_{lstm_layers}x{lstm_units_per_layer}_drop{dropout}_rec{recurrent_dropout}_lr{learning_rate}_bs{batch_size}_ep{epochs}_earlystp{early_stopping_monitor}{early_stopping_patience}{early_stopping_restore_best}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"

# %% [markdown]
# Compile the model.

# %%
# compile the model
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
# train the model
early_stopping = EarlyStopping(monitor=early_stopping_monitor, 
                               patience=early_stopping_patience, 
                               restore_best_weights=early_stopping_restore_best)

train_dataset = DynamicDataset(X_train_labeled, y_train_labeled, batch_size)
pseudo_labelling_callback = PseudoLabelingCallback(train_dataset, X_train_unlabeled, confidence_threshold=0.95, interval=5)

# %% [markdown]
# Train the Model

# %%
history = model.fit(train_dataset, 
                        epochs=epochs,
                        batch_size=batch_size, 
                        validation_data=validation_data,
                        callbacks=[early_stopping, pseudo_labelling_callback])
# Out:
# Epoch 1/1000
# d:\mgeo\projects\log-classification\venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# d:\mgeo\projects\log-classification\venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - accuracy: 0.2146 - loss: 1.3438 - val_accuracy: 0.2250 - val_loss: 1.3259
# Epoch 2/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 0.2227 - loss: 1.3468 - val_accuracy: 0.3000 - val_loss: 1.3000
# Epoch 3/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - accuracy: 0.2969 - loss: 1.3049 - val_accuracy: 0.3250 - val_loss: 1.2809
# Epoch 4/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.2891 - loss: 1.3033 - val_accuracy: 0.3500 - val_loss: 1.2611
# Epoch 5/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.3333 - loss: 1.2878
# [INFO] Epoch 5: Pseudo-labeling unlabeled data...
# best confidence: 0.6149279
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 581ms/step - accuracy: 0.3438 - loss: 1.2807 - val_accuracy: 0.3500 - val_loss: 1.2286
# Epoch 6/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 0.3719 - loss: 1.2228 - val_accuracy: 0.4250 - val_loss: 1.2038
# Epoch 7/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.5063 - loss: 1.1869 - val_accuracy: 0.5250 - val_loss: 1.1799
# Epoch 8/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 269ms/step - accuracy: 0.5604 - loss: 1.1628 - val_accuracy: 0.5500 - val_loss: 1.1652
# Epoch 9/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 0.6266 - loss: 1.1652 - val_accuracy: 0.5750 - val_loss: 1.1455
# Epoch 10/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5694 - loss: 1.1656
# [INFO] Epoch 10: Pseudo-labeling unlabeled data...
# best confidence: 0.6343015
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step - accuracy: 0.5833 - loss: 1.1589 - val_accuracy: 0.6250 - val_loss: 1.1252
# Epoch 11/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 0.6411 - loss: 1.1339 - val_accuracy: 0.6750 - val_loss: 1.0909
# Epoch 12/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.6526 - loss: 1.1176 - val_accuracy: 0.6750 - val_loss: 1.0751
# Epoch 13/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.6526 - loss: 1.0996 - val_accuracy: 0.6750 - val_loss: 1.0668
# Epoch 14/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.6781 - loss: 1.0831 - val_accuracy: 0.6750 - val_loss: 1.0510
# Epoch 15/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7708 - loss: 1.0186
# [INFO] Epoch 15: Pseudo-labeling unlabeled data...
# best confidence: 0.65324336
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step - accuracy: 0.7656 - loss: 1.0269 - val_accuracy: 0.6750 - val_loss: 1.0338
# Epoch 16/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 0.8099 - loss: 1.0327 - val_accuracy: 0.7000 - val_loss: 1.0180
# Epoch 17/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 0.8490 - loss: 0.9925 - val_accuracy: 0.7000 - val_loss: 1.0032
# Epoch 18/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 0.8070 - loss: 1.0166 - val_accuracy: 0.7000 - val_loss: 0.9877
# Epoch 19/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.7969 - loss: 0.9942 - val_accuracy: 0.7000 - val_loss: 0.9764
# Epoch 20/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.
# Epoch 252/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.9948 - loss: 0.0959 - val_accuracy: 0.9000 - val_loss: 0.2941
# Epoch 253/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step - accuracy: 1.0000 - loss: 0.0616 - val_accuracy: 0.9000 - val_loss: 0.2939
# Epoch 254/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 408ms/step - accuracy: 0.9522 - loss: 0.2149 - val_accuracy: 0.9000 - val_loss: 0.2934
# Epoch 255/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9809 - loss: 0.1612
# [INFO] Epoch 255: Pseudo-labeling unlabeled data...
# best confidence: 0.9502056
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 626ms/step - accuracy: 0.9831 - loss: 0.1503 - val_accuracy: 0.9000 - val_loss: 0.2932
# Epoch 256/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 0.9805 - loss: 0.1516 - val_accuracy: 0.9000 - val_loss: 0.2931
# Epoch 257/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.9527 - loss: 0.2118 - val_accuracy: 0.9000 - val_loss: 0.2938
# Epoch 258/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 0.9933 - loss: 0.0855 - val_accuracy: 0.9000 - val_loss: 0.2932
# Epoch 259/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.9805 - loss: 0.1299 - val_accuracy: 0.8750 - val_loss: 0.2958
# Epoch 260/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9809 - loss: 0.1735
# [INFO] Epoch 260: Pseudo-labeling unlabeled data...
# best confidence: 0.9516051
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step - accuracy: 0.9831 - loss: 0.1604 - val_accuracy: 0.8750 - val_loss: 0.2951
# Epoch 261/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 423ms/step - accuracy: 1.0000 - loss: 0.1300 - val_accuracy: 0.9000 - val_loss: 0.2946
# Epoch 262/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 1.0000 - loss: 0.0512 - val_accuracy: 0.9000 - val_loss: 0.2944
# Epoch 263/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.9934 - loss: 0.1007 - val_accuracy: 0.9000 - val_loss: 0.2936
# Epoch 264/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 275ms/step - accuracy: 0.9877 - loss: 0.1182 - val_accuracy: 0.9000 - val_loss: 0.2928
# Epoch 265/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9800 - loss: 0.1586
# [INFO] Epoch 265: Pseudo-labeling unlabeled data...
# best confidence: 0.9623383
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step - accuracy: 0.9817 - loss: 0.1487 - val_accuracy: 0.9000 - val_loss: 0.2929
# Epoch 266/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 0.9870 - loss: 0.0989 - val_accuracy: 0.9000 - val_loss: 0.2929
# Epoch 267/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.9805 - loss: 0.1258 - val_accuracy: 0.9000 - val_loss: 0.2924
# Epoch 268/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 0.9818 - loss: 0.1189 - val_accuracy: 0.9000 - val_loss: 0.2913
# Epoch 269/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 0.9727 - loss: 0.1703 - val_accuracy: 0.9000 - val_loss: 0.2887
# Epoch 270/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9583 - loss: 0.1781
# [INFO] Epoch 270: Pseudo-labeling unlabeled data...
# best confidence: 0.9501753
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 465ms/step - accuracy: 0.9609 - loss: 0.1746 - val_accuracy: 0.9000 - val_loss: 0.2872
# Epoch 271/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step - accuracy: 1.0000 - loss: 0.0633 - val_accuracy: 0.9000 - val_loss: 0.2842
# Epoch 272/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 1.0000 - loss: 0.0482 - val_accuracy: 0.9000 - val_loss: 0.2836
# Epoch 273/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 270ms/step - accuracy: 1.0000 - loss: 0.0563 - val_accuracy: 0.9000 - val_loss: 0.2833
# Epoch 274/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 0.9753 - loss: 0.1481 - val_accuracy: 0.9000 - val_loss: 0.2831
# Epoch 275/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9635 - loss: 0.2012
# [INFO] Epoch 275: Pseudo-labeling unlabeled data...
# best confidence: 0.94945204
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step - accuracy: 0.9648 - loss: 0.1913 - val_accuracy: 0.9000 - val_loss: 0.2823
# Epoch 276/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 1.0000 - loss: 0.0517 - val_accuracy: 0.9000 - val_loss: 0.2817
# Epoch 277/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 0.9936 - loss: 0.0765 - val_accuracy: 0.9000 - val_loss: 0.2813
# Epoch 278/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 0.9609 - loss: 0.1819 - val_accuracy: 0.9000 - val_loss: 0.2807
# Epoch 279/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 0.0509 - val_accuracy: 0.9000 - val_loss: 0.2803
# Epoch 280/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9885 - loss: 0.1051
# [INFO] Epoch 280: Pseudo-labeling unlabeled data...
# best confidence: 0.9507189
# [INFO] Adding 1 pseudo-labeled samples to training set.
# ...
# Epoch 908/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 1.0000 - loss: 0.0381 - val_accuracy: 0.9750 - val_loss: 0.1414
# Epoch 909/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.9750 - val_loss: 0.1411
# Epoch 910/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0391
# [INFO] Epoch 910: Pseudo-labeling unlabeled data...
# best confidence: 0.94983226
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 402ms/step - accuracy: 1.0000 - loss: 0.0355 - val_accuracy: 0.9750 - val_loss: 0.1407
# Epoch 911/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 1.0000 - loss: 0.0716 - val_accuracy: 0.9750 - val_loss: 0.1404
# Epoch 912/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.9750 - val_loss: 0.1401
# Epoch 913/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9750 - val_loss: 0.1400
# Epoch 914/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 1.0000 - loss: 0.0610 - val_accuracy: 0.9750 - val_loss: 0.1401
# Epoch 915/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0708
# [INFO] Epoch 915: Pseudo-labeling unlabeled data...
# best confidence: 0.9501613
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 404ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.9750 - val_loss: 0.1404
# Epoch 916/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 0.9750 - val_loss: 0.1405
# Epoch 917/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 1.0000 - loss: 0.0315 - val_accuracy: 0.9750 - val_loss: 0.1404
# Epoch 918/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 1.0000 - loss: 0.0235 - val_accuracy: 0.9750 - val_loss: 0.1403
# Epoch 919/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 0.9750 - val_loss: 0.1399
# Epoch 920/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0118
# [INFO] Epoch 920: Pseudo-labeling unlabeled data...
# best confidence: 0.94942784
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9750 - val_loss: 0.1397
# Epoch 921/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9750 - val_loss: 0.1396
# Epoch 922/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 1.0000 - loss: 0.0419 - val_accuracy: 0.9750 - val_loss: 0.1393
# Epoch 923/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.9750 - val_loss: 0.1393
# Epoch 924/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 1.0000 - loss: 0.0348 - val_accuracy: 0.9750 - val_loss: 0.1391
# Epoch 925/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 1.0000 - loss: 0.0185
# [INFO] Epoch 925: Pseudo-labeling unlabeled data...
# best confidence: 0.9493957
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - accuracy: 1.0000 - loss: 0.0237 - val_accuracy: 0.9750 - val_loss: 0.1390
# Epoch 926/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 1.0000 - loss: 0.0520 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 927/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 928/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0144 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 929/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0116 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 930/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 1.0000 - loss: 0.0329
# [INFO] Epoch 930: Pseudo-labeling unlabeled data...
# best confidence: 0.94946265
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 426ms/step - accuracy: 1.0000 - loss: 0.0346 - val_accuracy: 0.9750 - val_loss: 0.1391
# Epoch 931/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 1.0000 - loss: 0.0420 - val_accuracy: 0.9750 - val_loss: 0.1390
# Epoch 932/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 290ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9750 - val_loss: 0.1390
# Epoch 933/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.9750 - val_loss: 0.1391
# Epoch 934/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.9750 - val_loss: 0.1392
# Epoch 935/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 1.0000 - loss: 0.0608
# [INFO] Epoch 935: Pseudo-labeling unlabeled data...
# best confidence: 0.9504146
# [INFO] Adding 2 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - accuracy: 1.0000 - loss: 0.0552 - val_accuracy: 0.9750 - val_loss: 0.1395
# Epoch 936/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0660 - val_accuracy: 0.9750 - val_loss: 0.1398
# Epoch 937/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - accuracy: 1.0000 - loss: 0.0285 - val_accuracy: 0.9750 - val_loss: 0.1396
# Epoch 938/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 1.0000 - loss: 0.0398 - val_accuracy: 0.9750 - val_loss: 0.1395
# Epoch 939/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.9750 - val_loss: 0.1394
# Epoch 940/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0181
# [INFO] Epoch 940: Pseudo-labeling unlabeled data...
# best confidence: 0.95073235
# [INFO] Adding 2 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - accuracy: 1.0000 - loss: 0.0182 - val_accuracy: 0.9750 - val_loss: 0.1395
# Epoch 941/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 1.0000 - loss: 0.0155 - val_accuracy: 0.9750 - val_loss: 0.1396
# Epoch 942/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 0.9750 - val_loss: 0.1398
# Epoch 943/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9750 - val_loss: 0.1402
# Epoch 944/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.9750 - val_loss: 0.1406
# Epoch 945/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0324
# [INFO] Epoch 945: Pseudo-labeling unlabeled data...
# best confidence: 0.9507246
# [INFO] Adding 2 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 367ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.9750 - val_loss: 0.1410
# Epoch 946/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.9750 - val_loss: 0.1411
# Epoch 947/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 1.0000 - loss: 0.0472 - val_accuracy: 0.9750 - val_loss: 0.1410
# Epoch 948/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 1.0000 - loss: 0.0538 - val_accuracy: 0.9750 - val_loss: 0.1411
# Epoch 949/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 1.0000 - loss: 0.0405 - val_accuracy: 0.9750 - val_loss: 0.1410
# Epoch 950/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.0188
# [INFO] Epoch 950: Pseudo-labeling unlabeled data...
# best confidence: 0.95128345
# [INFO] Adding 2 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 393ms/step - accuracy: 1.0000 - loss: 0.0180 - val_accuracy: 0.9750 - val_loss: 0.1411
# Epoch 951/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - accuracy: 1.0000 - loss: 0.0585 - val_accuracy: 0.9750 - val_loss: 0.1410
# Epoch 952/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.9750 - val_loss: 0.1409
# Epoch 953/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 276ms/step - accuracy: 1.0000 - loss: 0.0505 - val_accuracy: 0.9750 - val_loss: 0.1403
# Epoch 954/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.9750 - val_loss: 0.1397
# Epoch 955/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0160
# [INFO] Epoch 955: Pseudo-labeling unlabeled data...
# best confidence: 0.950104
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.9750 - val_loss: 0.1392
# Epoch 956/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 272ms/step - accuracy: 1.0000 - loss: 0.0441 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 957/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9750 - val_loss: 0.1388
# Epoch 958/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9750 - val_loss: 0.1387
# Epoch 959/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 1.0000 - loss: 0.0371 - val_accuracy: 0.9750 - val_loss: 0.1387
# Epoch 960/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 1.0000 - loss: 0.0201
# [INFO] Epoch 960: Pseudo-labeling unlabeled data...
# best confidence: 0.95067686
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - accuracy: 1.0000 - loss: 0.0192 - val_accuracy: 0.9750 - val_loss: 0.1391
# Epoch 961/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9750 - val_loss: 0.1395
# Epoch 962/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.9750 - val_loss: 0.1396
# Epoch 963/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0120 - val_accuracy: 0.9750 - val_loss: 0.1398
# Epoch 964/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 311ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9750 - val_loss: 0.1401
# Epoch 965/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0185
# [INFO] Epoch 965: Pseudo-labeling unlabeled data...
# best confidence: 0.9504392
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 372ms/step - accuracy: 1.0000 - loss: 0.0188 - val_accuracy: 0.9750 - val_loss: 0.1405
# Epoch 966/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.9750 - val_loss: 0.1412
# Epoch 967/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step - accuracy: 1.0000 - loss: 0.0286 - val_accuracy: 0.9750 - val_loss: 0.1415
# Epoch 968/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9750 - val_loss: 0.1417
# Epoch 969/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0328 - val_accuracy: 0.9750 - val_loss: 0.1422
# Epoch 970/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0487
# [INFO] Epoch 970: Pseudo-labeling unlabeled data...
# best confidence: 0.94932866
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - accuracy: 1.0000 - loss: 0.0498 - val_accuracy: 0.9750 - val_loss: 0.1423
# Epoch 971/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 1.0000 - loss: 0.0364 - val_accuracy: 0.9750 - val_loss: 0.1421
# Epoch 972/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 248ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.9750 - val_loss: 0.1422
# Epoch 973/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - accuracy: 1.0000 - loss: 0.0404 - val_accuracy: 0.9750 - val_loss: 0.1421
# Epoch 974/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 1.0000 - loss: 0.0324 - val_accuracy: 0.9750 - val_loss: 0.1423
# Epoch 975/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 1.0000 - loss: 0.0134
# [INFO] Epoch 975: Pseudo-labeling unlabeled data...
# best confidence: 0.95020187
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 1.0000 - loss: 0.0140 - val_accuracy: 0.9750 - val_loss: 0.1428
# Epoch 976/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.9750 - val_loss: 0.1431
# Epoch 977/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 277ms/step - accuracy: 1.0000 - loss: 0.0458 - val_accuracy: 0.9750 - val_loss: 0.1427
# Epoch 978/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - accuracy: 1.0000 - loss: 0.0307 - val_accuracy: 0.9750 - val_loss: 0.1420
# Epoch 979/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step - accuracy: 1.0000 - loss: 0.0334 - val_accuracy: 0.9750 - val_loss: 0.1410
# Epoch 980/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0221
# [INFO] Epoch 980: Pseudo-labeling unlabeled data...
# best confidence: 0.95270485
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0198 - val_accuracy: 0.9750 - val_loss: 0.1399
# Epoch 981/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - accuracy: 1.0000 - loss: 0.0576 - val_accuracy: 0.9750 - val_loss: 0.1389
# Epoch 982/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.9750 - val_loss: 0.1382
# Epoch 983/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - accuracy: 1.0000 - loss: 0.0422 - val_accuracy: 0.9750 - val_loss: 0.1378
# Epoch 984/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.9750 - val_loss: 0.1375
# Epoch 985/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0130
# [INFO] Epoch 985: Pseudo-labeling unlabeled data...
# best confidence: 0.9483131
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 359ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.9750 - val_loss: 0.1370
# Epoch 986/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 288ms/step - accuracy: 1.0000 - loss: 0.0360 - val_accuracy: 0.9750 - val_loss: 0.1364
# Epoch 987/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step - accuracy: 1.0000 - loss: 0.0374 - val_accuracy: 0.9750 - val_loss: 0.1356
# Epoch 988/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.9750 - val_loss: 0.1347
# Epoch 989/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - accuracy: 1.0000 - loss: 0.0327 - val_accuracy: 0.9750 - val_loss: 0.1340
# Epoch 990/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0318
# [INFO] Epoch 990: Pseudo-labeling unlabeled data...
# best confidence: 0.94995964
# [INFO] No confident pseudo-labels found.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 1.0000 - loss: 0.0311 - val_accuracy: 0.9750 - val_loss: 0.1335
# Epoch 991/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9750 - val_loss: 0.1328
# Epoch 992/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 1.0000 - loss: 0.0421 - val_accuracy: 0.9750 - val_loss: 0.1317
# Epoch 993/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 291ms/step - accuracy: 1.0000 - loss: 0.0541 - val_accuracy: 0.9750 - val_loss: 0.1311
# Epoch 994/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9750 - val_loss: 0.1307
# Epoch 995/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0269
# [INFO] Epoch 995: Pseudo-labeling unlabeled data...
# best confidence: 0.9517833
# [INFO] Adding 2 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - accuracy: 1.0000 - loss: 0.0320 - val_accuracy: 0.9750 - val_loss: 0.1304
# Epoch 996/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 0.9750 - val_loss: 0.1302
# Epoch 997/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - accuracy: 1.0000 - loss: 0.0548 - val_accuracy: 0.9750 - val_loss: 0.1299
# Epoch 998/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 278ms/step - accuracy: 1.0000 - loss: 0.0360 - val_accuracy: 0.9750 - val_loss: 0.1220
# Epoch 999/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step - accuracy: 1.0000 - loss: 0.0632 - val_accuracy: 0.9750 - val_loss: 0.1220
# Epoch 1000/1000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0347
# [INFO] Epoch 1000: Pseudo-labeling unlabeled data...
# best confidence: 0.96331805
# [INFO] Adding 1 pseudo-labeled samples to training set.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.9750 - val_loss: 0.1216

# %% [markdown]
# # Evaluating and Testing
# Plot loss, validation loss, accuracy and validation accuracy of the training process.

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy and loss
plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

# plt.tight_layout()
if save_artifacts: plt.savefig(f"{filename}_train.png")
plt.show()

# %% [markdown]
# Optionally save the weights of the model

# %%
# optionally save the model weights
if save_artifacts: model.save(f"{filename}.keras")

# %% [markdown]
# Evaluate model and print scores

# %%
if save_artifacts:
    f = open(f"{filename}.txt", "w")
    ostd = sys.stdout
    sys.stdout = f

# Summary of the model
model.summary(print_fn = f.write if save_artifacts else None)

# Evaluate the model on test data
results = model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")

# Predictions
predictions = model.predict(X_test)
y_pred = np.argmax(predictions, axis=1)

# Classification report and F1 score
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1 Score (weighted): {f1:.4f}")

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
if save_artifacts: plt.savefig(f"{filename}.png")
plt.show()


# === Preview Predictions ===
for i in range(min(80, len(y_pred))):
    print(f"True: {y_test[i]}, Pred: {y_pred[i]}, Prob: {predictions[i]}")

if save_artifacts:
    sys.stdout = ostd
    f.close()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# Test on larger test dataset (3 newest files)

# %%
import numpy as np
import random
import os
import tensorflow as tf
from preprocessor import Preprocessor
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

from test_models import load_model, test_random_line

# %%
# preprocessor_path = "../data/preprocessors/preprocessor_20_smallest_files_100lpc_20ws_BERTencx16.zip"
test_preprocessor_path = "../data/preprocessors/preprocessor_3_newest_files_100lpc_20ws_BERTencx16.zip"
test_pp = Preprocessor.load(test_preprocessor_path)
print(test_pp.data.states_counts)
test_X, test_y = test_pp.data.as_xy_arrays()
# Out:
# defaultdict(<class 'int'>, {np.int64(0): 100, np.int64(3): 100, np.int64(2): 100, np.int64(1): 30})

# %%
# Get predictions
y_pred_probs = model.predict(test_X)
y_pred = y_pred_probs.argmax(axis=1)  # For softmax outputs

# True labels
y_true = test_y.argmax(axis=1) if test_y.ndim > 1 else test_y

# Compute metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

if save_artifacts:
    f = open(f"{filename}.txt", "w")
    ostd = sys.stdout
    sys.stdout = f

print("test with test data (3 newest files)")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")

if save_artifacts:
    f.close()
    sys.stdout = ostd
# Out:
# d:\mgeo\projects\log-classification\venv\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:258: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step

# %%
# Compute and plot confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title("Confusion Matrix")
if save_artifacts: plt.savefig(f"{filename}_test-confusionmatrix.png")
plt.show()
